# %% [markdown]
# <a href="https://colab.research.google.com/github/sivareddy147/APPLIED-DATA-MODELLING-AND-DEEP-LEARNING-FOR-ENGINEERS/blob/main/NANOCHIP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": []
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "code",
      "execution_count": 1,
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "blPoVcV9oNz_",
        "outputId": "2cae926a-5524-4940-ea24-71f6ea974086"
      },
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Average reward: 0.42\n"
          ]
        }
      ],
      "source": [
        "import numpy as np\n",
        "\n",
        "class RecommendationEnvironment:\n",
        "    def __init__(self, num_items):\n",
        "        self.num_items = num_items\n",
        "\n",
        "    def reset(self):\n",
        "        # Start from a random state (user context or history)\n",
        "        return np.random.randint(self.num_items)\n",
        "\n",
        "    def step(self, action):\n",
        "        # In this example, the reward is simply binary (1 if the recommended item is chosen, 0 otherwise)\n",
        "        return np.random.choice([0, 1])\n",
        "class QLearningAgent:\n",
        "    def __init__(self, num_actions, learning_rate=0.1, discount_factor=0.9, epsilon=0.1):\n",
        "        self.num_actions = num_actions\n",
        "        self.learning_rate = learning_rate\n",
        "        self.discount_factor = discount_factor\n",
        "        self.epsilon = epsilon\n",
        "        self.q_table = np.zeros(num_actions)\n",
        "\n",
        "    def choose_action(self, state):\n",
        "        if np.random.rand() < self.epsilon:\n",
        "            return np.random.randint(self.num_actions)\n",
        "        else:\n",
        "            return np.argmax(self.q_table)\n",
        "\n",
        "    def update_q_table(self, state, action, reward):\n",
        "        td_target = reward\n",
        "        td_error = td_target - self.q_table[action]\n",
        "        self.q_table[action] += self.learning_rate * td_error\n",
        "\n",
        "# Define a simple evaluation function to simulate recommendation episodes\n",
        "def evaluate(agent, env, num_episodes=100):\n",
        "    total_rewards = 0\n",
        "    for _ in range(num_episodes):\n",
        "        state = env.reset()\n",
        "        action = agent.choose_action(state)\n",
        "        reward = env.step(action)\n",
        "        total_rewards += reward\n",
        "    average_reward = total_rewards / num_episodes\n",
        "    return average_reward\n",
        "\n",
        "def main():\n",
        "\n",
        "    num_items = 10\n",
        "    env = RecommendationEnvironment(num_items)\n",
        "    agent = QLearningAgent(num_items)\n",
        "\n",
        "    # Train the agent\n",
        "    num_episodes = 1000\n",
        "    for _ in range(num_episodes):\n",
        "        state = env.reset()\n",
        "        action = agent.choose_action(state)\n",
        "        reward = env.step(action)\n",
        "        agent.update_q_table(state, action, reward)\n",
        "\n",
        "    # Evaluate the agent\n",
        "    average_reward = evaluate(agent, env)\n",
        "    print(\"Average reward:\", average_reward)\n",
        "\n",
        "if __name__ == \"__main__\":\n",
        "    main()\n"
      ]
    }
  ]
}
# Out:
# {'nbformat': 4,
#  'nbformat_minor': 0,
#  'metadata': {'colab': {'provenance': []},
#   'kernelspec': {'name': 'python3', 'display_name': 'Python 3'},
#   'language_info': {'name': 'python'}},
#  'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'blPoVcV9oNz_',
#     'outputId': '2cae926a-5524-4940-ea24-71f6ea974086'},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': ['Average reward: 0.42\n']}],
#    'source': ['import numpy as np\n',
#     '\n',
#     'class RecommendationEnvironment:\n',
#     '    def __init__(self, num_items):\n',
#     '        self.num_items = num_items\n',
#     '\n',
#     '    def reset(self):\n',
#     '        # Start from a random state (user context or history)\n',
#     '        return np.random.randint(self.num_items)\n',
#     '\n',
#     '    def step(self, action):\n',
# ...

# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": []
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "markdown",
      "source": [
        "\n",
        "\n",
        "*  An Environment, which an agent will interact with, to learn to reach a goal or perform an action.\n",
        "\n",
        "A Reward if the action performed by the model is bringing\n",
        "us closer to the goal/is leading to the goal. This is done to train the model in the right direction.\n",
        "\n",
        "A negative reward if it performs an action that will not lead to the goal to prevent it from learning in the wrong direction.\n",
        "\n"
      ],
      "metadata": {
        "id": "l9nMxmd0tv99"
      }
    },
    {
      "cell_type": "code",
      "source": [
        "import numpy as np\n",
        "\n",
        "class PricingEnvironment:\n",
        "    def __init__(self, max_demand, max_price):\n",
        "        self.max_demand = max_demand\n",
        "        self.max_price = max_price\n",
        "        self.current_demand = 0\n",
        "\n",
        "    def reset(self):\n",
        "        self.current_demand = np.random.randint(1, self.max_demand + 1)\n",
        "        return self.current_demand\n",
        "\n",
        "    def step(self, price):\n",
        "        revenue = min(price, self.current_demand) * price\n",
        "        self.current_demand -= min(price, self.current_demand)\n",
        "        done = self.current_demand == 0\n",
        "        return revenue, done\n",
        "\n",
        "class QLearningAgent:\n",
        "    def __init__(self, num_prices, max_price, learning_rate=0.1, gamma=0.9, epsilon=0.1):\n",
        "        self.num_prices = num_prices\n",
        "        self.max_price = max_price\n",
        "        self.learning_rate = learning_rate\n",
        "        self.gamma = gamma\n",
        "        self.epsilon = epsilon\n",
        "        self.q_table = np.zeros((num_prices,))\n",
        "\n",
        "    def choose_price(self, demand):\n",
        "        if np.random.rand() < self.epsilon:\n",
        "            return np.random.randint(1, self.max_price + 1)\n",
        "        else:\n",
        "            return np.argmax(self.q_table) + 1\n",
        "\n",
        "    def update_q_table(self, price, demand, revenue):\n",
        "        old_q_value = self.q_table[price - 1]\n",
        "        max_future_q_value = np.max(self.q_table)\n",
        "        new_q_value = (1 - self.learning_rate) * old_q_value + self.learning_rate * (revenue + self.gamma * max_future_q_value)\n",
        "        self.q_table[price - 1] = new_q_value\n",
        "\n",
        "# Parameters\n",
        "max_demand = 10\n",
        "max_price = 10\n",
        "num_episodes = 1000\n",
        "learning_rate = 0.1\n",
        "gamma = 0.9\n",
        "epsilon = 0.1\n",
        "\n",
        "# Initialize environment and agent\n",
        "env = PricingEnvironment(max_demand, max_price)\n",
        "agent = QLearningAgent(num_prices=max_price, max_price=max_price, learning_rate=learning_rate, gamma=gamma, epsilon=epsilon)\n",
        "\n",
        "# Training loop\n",
        "for episode in range(num_episodes):\n",
        "    demand = env.reset()\n",
        "    done = False\n",
        "    total_revenue = 0\n",
        "    while not done:\n",
        "        price = agent.choose_price(demand)\n",
        "        revenue, done = env.step(price)\n",
        "        total_revenue += revenue\n",
        "        agent.update_q_table(price, demand, revenue)\n",
        "    print(f\"Episode {episode + 1}, Total Revenue: ${total_revenue:.2f}\")\n",
        "\n",
        "# Once trained, use the agent to choose prices\n",
        "demand = env.reset()\n",
        "optimal_price = agent.choose_price(demand)\n",
        "print(f\"Optimal Price for current demand ({demand}): ${optimal_price}\")\n"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "lppSPDt1stl-",
        "outputId": "9cb11dfd-2291-49b2-9208-ce06046d32d8"
      },
      "execution_count": 20,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Episode 1, Total Revenue: $41.00\n",
            "Episode 2, Total Revenue: $21.00\n",
            "Episode 3, Total Revenue: $54.00\n",
            "Episode 4, Total Revenue: $81.00\n",
            "Episode 5, Total Revenue: $72.00\n",
            "Episode 6, Total Revenue: $72.00\n",
            "Episode 7, Total Revenue: $45.00\n",
            "Episode 8, Total Revenue: $63.00\n",
            "Episode 9, Total Revenue: $63.00\n",
            "Episode 10, Total Revenue: $90.00\n",
            "Episode 11, Total Revenue: $18.00\n",
            "Episode 12, Total Revenue: $45.00\n",
            "Episode 13, Total Revenue: $45.00\n",
            "Episode 14, Total Revenue: $9.00\n",
            "Episode 15, Total Revenue: $27.00\n",
            "Episode 16, Total Revenue: $16.00\n",
            "Episode 17, Total Revenue: $73.00\n",
            "Episode 18, Total Revenue: $36.00\n",
            "Episode 19, Total Revenue: $27.00\n",
            "Episode 20, Total Revenue: $36.00\n",
            "Episode 21, Total Revenue: $90.00\n",
            "Episode 22, Total Revenue: $9.00\n",
            "Episode 23, Total Revenue: $9.00\n",
            "Episode 24, Total Revenue: $27.00\n",
            "Episode 25, Total Revenue: $81.00\n",
            "Episode 26, Total Revenue: $27.00\n",
            "Episode 27, Total Revenue: $54.00\n",
            "Episode 28, Total Revenue: $63.00\n",
            "Episode 29, Total Revenue: $45.00\n",
            "Episode 30, Total Revenue: $63.00\n",
            "Episode 31, Total Revenue: $18.00\n",
            "Episode 32, Total Revenue: $45.00\n",
            "Episode 33, Total Revenue: $81.00\n",
            "Episode 34, Total Revenue: $81.00\n",
            "Episode 35, Total Revenue: $54.00\n",
            "Episode 36, Total Revenue: $36.00\n",
            "Episode 37, Total Revenue: $63.00\n",
            "Episode 38, Total Revenue: $54.00\n",
            "Episode 39, Total Revenue: $63.00\n",
            "Episode 40, Total Revenue: $54.00\n",
            "Episode 41, Total Revenue: $45.00\n",
            "Episode 42, Total Revenue: $45.00\n",
            "Episode 43, Total Revenue: $18.00\n",
            "Episode 44, Total Revenue: $18.00\n",
            "Episode 45, Total Revenue: $9.00\n",
            "Episode 46, Total Revenue: $81.00\n",
            "Episode 47, Total Revenue: $90.00\n",
            "Episode 48, Total Revenue: $27.00\n",
            "Episode 49, Total Revenue: $54.00\n",
            "Episode 50, Total Revenue: $36.00\n",
            "Episode 51, Total Revenue: $87.00\n",
            "Episode 52, Total Revenue: $54.00\n",
            "Episode 53, Total Revenue: $54.00\n",
            "Episode 54, Total Revenue: $63.00\n",
            "Episode 55, Total Revenue: $63.00\n",
            "Episode 56, Total Revenue: $90.00\n",
            "Episode 57, Total Revenue: $63.00\n",
            "Episode 58, Total Revenue: $27.00\n",
            "Episode 59, Total Revenue: $72.00\n",
            "Episode 60, Total Revenue: $54.00\n",
            "Episode 61, Total Revenue: $45.00\n",
            "Episode 62, Total Revenue: $9.00\n",
            "Episode 63, Total Revenue: $27.00\n",
            "Episode 64, Total Revenue: $9.00\n",
            "Episode 65, Total Revenue: $63.00\n",
            "Episode 66, Total Revenue: $27.00\n",
            "Episode 67, Total Revenue: $18.00\n",
            "Episode 68, Total Revenue: $9.00\n",
            "Episode 69, Total Revenue: $27.00\n",
            "Episode 70, Total Revenue: $90.00\n",
            "Episode 71, Total Revenue: $18.00\n",
            "Episode 72, Total Revenue: $45.00\n",
            "Episode 73, Total Revenue: $24.00\n",
            "Episode 74, Total Revenue: $81.00\n",
            "Episode 75, Total Revenue: $52.00\n",
            "Episode 76, Total Revenue: $36.00\n",
            "Episode 77, Total Revenue: $36.00\n",
            "Episode 78, Total Revenue: $24.00\n",
            "Episode 79, Total Revenue: $36.00\n",
            "Episode 80, Total Revenue: $90.00\n",
            "Episode 81, Total Revenue: $36.00\n",
            "Episode 82, Total Revenue: $27.00\n",
            "Episode 83, Total Revenue: $27.00\n",
            "Episode 84, Total Revenue: $18.00\n",
            "Episode 85, Total Revenue: $90.00\n",
            "Episode 86, Total Revenue: $81.00\n",
            "Episode 87, Total Revenue: $36.00\n",
            "Episode 88, Total Revenue: $45.00\n",
            "Episode 89, Total Revenue: $100.00\n",
            "Episode 90, Total Revenue: $27.00\n",
            "Episode 91, Total Revenue: $54.00\n",
            "Episode 92, Total Revenue: $9.00\n",
            "Episode 93, Total Revenue: $90.00\n",
            "Episode 94, Total Revenue: $90.00\n",
            "Episode 95, Total Revenue: $63.00\n",
            "Episode 96, Total Revenue: $27.00\n",
            "Episode 97, Total Revenue: $9.00\n",
            "Episode 98, Total Revenue: $36.00\n",
            "Episode 99, Total Revenue: $18.00\n",
            "Episode 100, Total Revenue: $9.00\n",
            "Episode 101, Total Revenue: $45.00\n",
            "Episode 102, Total Revenue: $72.00\n",
            "Episode 103, Total Revenue: $90.00\n",
            "Episode 104, Total Revenue: $36.00\n",
            "Episode 105, Total Revenue: $56.00\n",
            "Episode 106, Total Revenue: $81.00\n",
            "Episode 107, Total Revenue: $63.00\n",
            "Episode 108, Total Revenue: $63.00\n",
            "Episode 109, Total Revenue: $81.00\n",
            "Episode 110, Total Revenue: $36.00\n",
            "Episode 111, Total Revenue: $36.00\n",
            "Episode 112, Total Revenue: $81.00\n",
            "Episode 113, Total Revenue: $81.00\n",
            "Episode 114, Total Revenue: $90.00\n",
            "Episode 115, Total Revenue: $11.00\n",
            "Episode 116, Total Revenue: $18.00\n",
            "Episode 117, Total Revenue: $45.00\n",
            "Episode 118, Total Revenue: $9.00\n",
            "Episode 119, Total Revenue: $72.00\n",
            "Episode 120, Total Revenue: $27.00\n",
            "Episode 121, Total Revenue: $100.00\n",
            "Episode 122, Total Revenue: $70.00\n",
            "Episode 123, Total Revenue: $18.00\n",
            "Episode 124, Total Revenue: $81.00\n",
            "Episode 125, Total Revenue: $63.00\n",
            "Episode 126, Total Revenue: $9.00\n",
            "Episode 127, Total Revenue: $72.00\n",
            "Episode 128, Total Revenue: $27.00\n",
            "Episode 129, Total Revenue: $90.00\n",
            "Episode 130, Total Revenue: $81.00\n",
            "Episode 131, Total Revenue: $90.00\n",
            "Episode 132, Total Revenue: $54.00\n",
            "Episode 133, Total Revenue: $36.00\n",
            "Episode 134, Total Revenue: $54.00\n",
            "Episode 135, Total Revenue: $36.00\n",
            "Episode 136, Total Revenue: $72.00\n",
            "Episode 137, Total Revenue: $36.00\n",
            "Episode 138, Total Revenue: $63.00\n",
            "Episode 139, Total Revenue: $72.00\n",
            "Episode 140, Total Revenue: $27.00\n",
            "Episode 141, Total Revenue: $36.00\n",
            "Episode 142, Total Revenue: $36.00\n",
            "Episode 143, Total Revenue: $54.00\n",
            "Episode 144, Total Revenue: $72.00\n",
            "Episode 145, Total Revenue: $45.00\n",
            "Episode 146, Total Revenue: $45.00\n",
            "Episode 147, Total Revenue: $15.00\n",
            "Episode 148, Total Revenue: $27.00\n",
            "Episode 149, Total Revenue: $9.00\n",
            "Episode 150, Total Revenue: $72.00\n",
            "Episode 151, Total Revenue: $36.00\n",
            "Episode 152, Total Revenue: $81.00\n",
            "Episode 153, Total Revenue: $90.00\n",
            "Episode 154, Total Revenue: $72.00\n",
            "Episode 155, Total Revenue: $27.00\n",
            "Episode 156, Total Revenue: $63.00\n",
            "Episode 157, Total Revenue: $18.00\n",
            "Episode 158, Total Revenue: $16.00\n",
            "Episode 159, Total Revenue: $27.00\n",
            "Episode 160, Total Revenue: $72.00\n",
            "Episode 161, Total Revenue: $9.00\n",
            "Episode 162, Total Revenue: $72.00\n",
            "Episode 163, Total Revenue: $18.00\n",
            "Episode 164, Total Revenue: $63.00\n",
            "Episode 165, Total Revenue: $70.00\n",
            "Episode 166, Total Revenue: $81.00\n",
            "Episode 167, Total Revenue: $63.00\n",
            "Episode 168, Total Revenue: $36.00\n",
            "Episode 169, Total Revenue: $72.00\n",
            "Episode 170, Total Revenue: $27.00\n",
            "Episode 171, Total Revenue: $43.00\n",
            "Episode 172, Total Revenue: $9.00\n",
            "Episode 173, Total Revenue: $90.00\n",
            "Episode 174, Total Revenue: $18.00\n",
            "Episode 175, Total Revenue: $81.00\n",
            "Episode 176, Total Revenue: $90.00\n",
            "Episode 177, Total Revenue: $54.00\n",
            "Episode 178, Total Revenue: $63.00\n",
            "Episode 179, Total Revenue: $27.00\n",
            "Episode 180, Total Revenue: $54.00\n",
            "Episode 181, Total Revenue: $90.00\n",
            "Episode 182, Total Revenue: $72.00\n",
            "Episode 183, Total Revenue: $18.00\n",
            "Episode 184, Total Revenue: $54.00\n",
            "Episode 185, Total Revenue: $90.00\n",
            "Episode 186, Total Revenue: $27.00\n",
            "Episode 187, Total Revenue: $63.00\n",
            "Episode 188, Total Revenue: $45.00\n",
            "Episode 189, Total Revenue: $45.00\n",
            "Episode 190, Total Revenue: $90.00\n",
            "Episode 191, Total Revenue: $81.00\n",
            "Episode 192, Total Revenue: $27.00\n",
            "Episode 193, Total Revenue: $9.00\n",
            "Episode 194, Total Revenue: $9.00\n",
            "Episode 195, Total Revenue: $54.00\n",
            "Episode 196, Total Revenue: $36.00\n",
            "Episode 197, Total Revenue: $18.00\n",
            "Episode 198, Total Revenue: $64.00\n",
            "Episode 199, Total Revenue: $81.00\n",
            "Episode 200, Total Revenue: $27.00\n",
            "Episode 201, Total Revenue: $81.00\n",
            "Episode 202, Total Revenue: $72.00\n",
            "Episode 203, Total Revenue: $27.00\n",
            "Episode 204, Total Revenue: $9.00\n",
            "Episode 205, Total Revenue: $45.00\n",
            "Episode 206, Total Revenue: $18.00\n",
            "Episode 207, Total Revenue: $54.00\n",
            "Episode 208, Total Revenue: $36.00\n",
            "Episode 209, Total Revenue: $45.00\n",
            "Episode 210, Total Revenue: $36.00\n",
            "Episode 211, Total Revenue: $54.00\n",
            "Episode 212, Total Revenue: $72.00\n",
            "Episode 213, Total Revenue: $9.00\n",
            "Episode 214, Total Revenue: $27.00\n",
            "Episode 215, Total Revenue: $90.00\n",
            "Episode 216, Total Revenue: $90.00\n",
            "Episode 217, Total Revenue: $54.00\n",
            "Episode 218, Total Revenue: $81.00\n",
            "Episode 219, Total Revenue: $72.00\n",
            "Episode 220, Total Revenue: $18.00\n",
            "Episode 221, Total Revenue: $81.00\n",
            "Episode 222, Total Revenue: $72.00\n",
            "Episode 223, Total Revenue: $27.00\n",
            "Episode 224, Total Revenue: $27.00\n",
            "Episode 225, Total Revenue: $45.00\n",
            "Episode 226, Total Revenue: $18.00\n",
            "Episode 227, Total Revenue: $72.00\n",
            "Episode 228, Total Revenue: $90.00\n",
            "Episode 229, Total Revenue: $9.00\n",
            "Episode 230, Total Revenue: $16.00\n",
            "Episode 231, Total Revenue: $45.00\n",
            "Episode 232, Total Revenue: $36.00\n",
            "Episode 233, Total Revenue: $85.00\n",
            "Episode 234, Total Revenue: $27.00\n",
            "Episode 235, Total Revenue: $9.00\n",
            "Episode 236, Total Revenue: $81.00\n",
            "Episode 237, Total Revenue: $36.00\n",
            "Episode 238, Total Revenue: $27.00\n",
            "Episode 239, Total Revenue: $9.00\n",
            "Episode 240, Total Revenue: $21.00\n",
            "Episode 241, Total Revenue: $54.00\n",
            "Episode 242, Total Revenue: $18.00\n",
            "Episode 243, Total Revenue: $45.00\n",
            "Episode 244, Total Revenue: $27.00\n",
            "Episode 245, Total Revenue: $45.00\n",
            "Episode 246, Total Revenue: $9.00\n",
            "Episode 247, Total Revenue: $54.00\n",
            "Episode 248, Total Revenue: $27.00\n",
            "Episode 249, Total Revenue: $45.00\n",
            "Episode 250, Total Revenue: $63.00\n",
            "Episode 251, Total Revenue: $27.00\n",
            "Episode 252, Total Revenue: $18.00\n",
            "Episode 253, Total Revenue: $81.00\n",
            "Episode 254, Total Revenue: $72.00\n",
            "Episode 255, Total Revenue: $81.00\n",
            "Episode 256, Total Revenue: $9.00\n",
            "Episode 257, Total Revenue: $27.00\n",
            "Episode 258, Total Revenue: $90.00\n",
            "Episode 259, Total Revenue: $52.00\n",
            "Episode 260, Total Revenue: $87.00\n",
            "Episode 261, Total Revenue: $72.00\n",
            "Episode 262, Total Revenue: $63.00\n",
            "Episode 263, Total Revenue: $90.00\n",
            "Episode 264, Total Revenue: $9.00\n",
            "Episode 265, Total Revenue: $54.00\n",
            "Episode 266, Total Revenue: $9.00\n",
            "Episode 267, Total Revenue: $49.00\n",
            "Episode 268, Total Revenue: $45.00\n",
            "Episode 269, Total Revenue: $45.00\n",
            "Episode 270, Total Revenue: $54.00\n",
            "Episode 271, Total Revenue: $45.00\n",
            "Episode 272, Total Revenue: $87.00\n",
            "Episode 273, Total Revenue: $36.00\n",
            "Episode 274, Total Revenue: $10.00\n",
            "Episode 275, Total Revenue: $10.00\n",
            "Episode 276, Total Revenue: $27.00\n",
            "Episode 277, Total Revenue: $63.00\n",
            "Episode 278, Total Revenue: $81.00\n",
            "Episode 279, Total Revenue: $36.00\n",
            "Episode 280, Total Revenue: $18.00\n",
            "Episode 281, Total Revenue: $9.00\n",
            "Episode 282, Total Revenue: $54.00\n",
            "Episode 283, Total Revenue: $63.00\n",
            "Episode 284, Total Revenue: $9.00\n",
            "Episode 285, Total Revenue: $54.00\n",
            "Episode 286, Total Revenue: $54.00\n",
            "Episode 287, Total Revenue: $90.00\n",
            "Episode 288, Total Revenue: $36.00\n",
            "Episode 289, Total Revenue: $18.00\n",
            "Episode 290, Total Revenue: $9.00\n",
            "Episode 291, Total Revenue: $63.00\n",
            "Episode 292, Total Revenue: $45.00\n",
            "Episode 293, Total Revenue: $90.00\n",
            "Episode 294, Total Revenue: $63.00\n",
            "Episode 295, Total Revenue: $9.00\n",
            "Episode 296, Total Revenue: $5.00\n",
            "Episode 297, Total Revenue: $9.00\n",
            "Episode 298, Total Revenue: $9.00\n",
            "Episode 299, Total Revenue: $36.00\n",
            "Episode 300, Total Revenue: $18.00\n",
            "Episode 301, Total Revenue: $9.00\n",
            "Episode 302, Total Revenue: $27.00\n",
            "Episode 303, Total Revenue: $90.00\n",
            "Episode 304, Total Revenue: $90.00\n",
            "Episode 305, Total Revenue: $55.00\n",
            "Episode 306, Total Revenue: $45.00\n",
            "Episode 307, Total Revenue: $90.00\n",
            "Episode 308, Total Revenue: $9.00\n",
            "Episode 309, Total Revenue: $81.00\n",
            "Episode 310, Total Revenue: $72.00\n",
            "Episode 311, Total Revenue: $36.00\n",
            "Episode 312, Total Revenue: $72.00\n",
            "Episode 313, Total Revenue: $15.00\n",
            "Episode 314, Total Revenue: $18.00\n",
            "Episode 315, Total Revenue: $18.00\n",
            "Episode 316, Total Revenue: $27.00\n",
            "Episode 317, Total Revenue: $72.00\n",
            "Episode 318, Total Revenue: $27.00\n",
            "Episode 319, Total Revenue: $54.00\n",
            "Episode 320, Total Revenue: $18.00\n",
            "Episode 321, Total Revenue: $81.00\n",
            "Episode 322, Total Revenue: $27.00\n",
            "Episode 323, Total Revenue: $81.00\n",
            "Episode 324, Total Revenue: $45.00\n",
            "Episode 325, Total Revenue: $9.00\n",
            "Episode 326, Total Revenue: $16.00\n",
            "Episode 327, Total Revenue: $54.00\n",
            "Episode 328, Total Revenue: $45.00\n",
            "Episode 329, Total Revenue: $45.00\n",
            "Episode 330, Total Revenue: $72.00\n",
            "Episode 331, Total Revenue: $81.00\n",
            "Episode 332, Total Revenue: $72.00\n",
            "Episode 333, Total Revenue: $18.00\n",
            "Episode 334, Total Revenue: $63.00\n",
            "Episode 335, Total Revenue: $36.00\n",
            "Episode 336, Total Revenue: $63.00\n",
            "Episode 337, Total Revenue: $45.00\n",
            "Episode 338, Total Revenue: $36.00\n",
            "Episode 339, Total Revenue: $27.00\n",
            "Episode 340, Total Revenue: $18.00\n",
            "Episode 341, Total Revenue: $81.00\n",
            "Episode 342, Total Revenue: $36.00\n",
            "Episode 343, Total Revenue: $27.00\n",
            "Episode 344, Total Revenue: $45.00\n",
            "Episode 345, Total Revenue: $9.00\n",
            "Episode 346, Total Revenue: $58.00\n",
            "Episode 347, Total Revenue: $61.00\n",
            "Episode 348, Total Revenue: $81.00\n",
            "Episode 349, Total Revenue: $63.00\n",
            "Episode 350, Total Revenue: $60.00\n",
            "Episode 351, Total Revenue: $54.00\n",
            "Episode 352, Total Revenue: $54.00\n",
            "Episode 353, Total Revenue: $21.00\n",
            "Episode 354, Total Revenue: $45.00\n",
            "Episode 355, Total Revenue: $18.00\n",
            "Episode 356, Total Revenue: $54.00\n",
            "Episode 357, Total Revenue: $45.00\n",
            "Episode 358, Total Revenue: $82.00\n",
            "Episode 359, Total Revenue: $27.00\n",
            "Episode 360, Total Revenue: $90.00\n",
            "Episode 361, Total Revenue: $72.00\n",
            "Episode 362, Total Revenue: $18.00\n",
            "Episode 363, Total Revenue: $72.00\n",
            "Episode 364, Total Revenue: $28.00\n",
            "Episode 365, Total Revenue: $32.00\n",
            "Episode 366, Total Revenue: $36.00\n",
            "Episode 367, Total Revenue: $81.00\n",
            "Episode 368, Total Revenue: $90.00\n",
            "Episode 369, Total Revenue: $72.00\n",
            "Episode 370, Total Revenue: $9.00\n",
            "Episode 371, Total Revenue: $81.00\n",
            "Episode 372, Total Revenue: $25.00\n",
            "Episode 373, Total Revenue: $72.00\n",
            "Episode 374, Total Revenue: $63.00\n",
            "Episode 375, Total Revenue: $55.00\n",
            "Episode 376, Total Revenue: $27.00\n",
            "Episode 377, Total Revenue: $72.00\n",
            "Episode 378, Total Revenue: $9.00\n",
            "Episode 379, Total Revenue: $45.00\n",
            "Episode 380, Total Revenue: $63.00\n",
            "Episode 381, Total Revenue: $81.00\n",
            "Episode 382, Total Revenue: $27.00\n",
            "Episode 383, Total Revenue: $18.00\n",
            "Episode 384, Total Revenue: $5.00\n",
            "Episode 385, Total Revenue: $81.00\n",
            "Episode 386, Total Revenue: $81.00\n",
            "Episode 387, Total Revenue: $54.00\n",
            "Episode 388, Total Revenue: $90.00\n",
            "Episode 389, Total Revenue: $27.00\n",
            "Episode 390, Total Revenue: $54.00\n",
            "Episode 391, Total Revenue: $90.00\n",
            "Episode 392, Total Revenue: $72.00\n",
            "Episode 393, Total Revenue: $90.00\n",
            "Episode 394, Total Revenue: $45.00\n",
            "Episode 395, Total Revenue: $9.00\n",
            "Episode 396, Total Revenue: $81.00\n",
            "Episode 397, Total Revenue: $36.00\n",
            "Episode 398, Total Revenue: $90.00\n",
            "Episode 399, Total Revenue: $45.00\n",
            "Episode 400, Total Revenue: $27.00\n",
            "Episode 401, Total Revenue: $18.00\n",
            "Episode 402, Total Revenue: $72.00\n",
            "Episode 403, Total Revenue: $18.00\n",
            "Episode 404, Total Revenue: $90.00\n",
            "Episode 405, Total Revenue: $36.00\n",
            "Episode 406, Total Revenue: $18.00\n",
            "Episode 407, Total Revenue: $9.00\n",
            "Episode 408, Total Revenue: $81.00\n",
            "Episode 409, Total Revenue: $81.00\n",
            "Episode 410, Total Revenue: $54.00\n",
            "Episode 411, Total Revenue: $9.00\n",
            "Episode 412, Total Revenue: $89.00\n",
            "Episode 413, Total Revenue: $72.00\n",
            "Episode 414, Total Revenue: $90.00\n",
            "Episode 415, Total Revenue: $9.00\n",
            "Episode 416, Total Revenue: $18.00\n",
            "Episode 417, Total Revenue: $63.00\n",
            "Episode 418, Total Revenue: $27.00\n",
            "Episode 419, Total Revenue: $72.00\n",
            "Episode 420, Total Revenue: $72.00\n",
            "Episode 421, Total Revenue: $63.00\n",
            "Episode 422, Total Revenue: $84.00\n",
            "Episode 423, Total Revenue: $45.00\n",
            "Episode 424, Total Revenue: $6.00\n",
            "Episode 425, Total Revenue: $27.00\n",
            "Episode 426, Total Revenue: $45.00\n",
            "Episode 427, Total Revenue: $54.00\n",
            "Episode 428, Total Revenue: $18.00\n",
            "Episode 429, Total Revenue: $9.00\n",
            "Episode 430, Total Revenue: $36.00\n",
            "Episode 431, Total Revenue: $9.00\n",
            "Episode 432, Total Revenue: $18.00\n",
            "Episode 433, Total Revenue: $64.00\n",
            "Episode 434, Total Revenue: $81.00\n",
            "Episode 435, Total Revenue: $9.00\n",
            "Episode 436, Total Revenue: $27.00\n",
            "Episode 437, Total Revenue: $81.00\n",
            "Episode 438, Total Revenue: $36.00\n",
            "Episode 439, Total Revenue: $90.00\n",
            "Episode 440, Total Revenue: $90.00\n",
            "Episode 441, Total Revenue: $18.00\n",
            "Episode 442, Total Revenue: $72.00\n",
            "Episode 443, Total Revenue: $36.00\n",
            "Episode 444, Total Revenue: $27.00\n",
            "Episode 445, Total Revenue: $25.00\n",
            "Episode 446, Total Revenue: $18.00\n",
            "Episode 447, Total Revenue: $18.00\n",
            "Episode 448, Total Revenue: $18.00\n",
            "Episode 449, Total Revenue: $72.00\n",
            "Episode 450, Total Revenue: $54.00\n",
            "Episode 451, Total Revenue: $90.00\n",
            "Episode 452, Total Revenue: $45.00\n",
            "Episode 453, Total Revenue: $9.00\n",
            "Episode 454, Total Revenue: $36.00\n",
            "Episode 455, Total Revenue: $45.00\n",
            "Episode 456, Total Revenue: $72.00\n",
            "Episode 457, Total Revenue: $72.00\n",
            "Episode 458, Total Revenue: $63.00\n",
            "Episode 459, Total Revenue: $27.00\n",
            "Episode 460, Total Revenue: $18.00\n",
            "Episode 461, Total Revenue: $36.00\n",
            "Episode 462, Total Revenue: $27.00\n",
            "Episode 463, Total Revenue: $90.00\n",
            "Episode 464, Total Revenue: $45.00\n",
            "Episode 465, Total Revenue: $63.00\n",
            "Episode 466, Total Revenue: $27.00\n",
            "Episode 467, Total Revenue: $9.00\n",
            "Episode 468, Total Revenue: $63.00\n",
            "Episode 469, Total Revenue: $72.00\n",
            "Episode 470, Total Revenue: $70.00\n",
            "Episode 471, Total Revenue: $81.00\n",
            "Episode 472, Total Revenue: $63.00\n",
            "Episode 473, Total Revenue: $27.00\n",
            "Episode 474, Total Revenue: $63.00\n",
            "Episode 475, Total Revenue: $45.00\n",
            "Episode 476, Total Revenue: $45.00\n",
            "Episode 477, Total Revenue: $54.00\n",
            "Episode 478, Total Revenue: $89.00\n",
            "Episode 479, Total Revenue: $18.00\n",
            "Episode 480, Total Revenue: $9.00\n",
            "Episode 481, Total Revenue: $90.00\n",
            "Episode 482, Total Revenue: $72.00\n",
            "Episode 483, Total Revenue: $45.00\n",
            "Episode 484, Total Revenue: $63.00\n",
            "Episode 485, Total Revenue: $63.00\n",
            "Episode 486, Total Revenue: $18.00\n",
            "Episode 487, Total Revenue: $45.00\n",
            "Episode 488, Total Revenue: $36.00\n",
            "Episode 489, Total Revenue: $63.00\n",
            "Episode 490, Total Revenue: $61.00\n",
            "Episode 491, Total Revenue: $90.00\n",
            "Episode 492, Total Revenue: $63.00\n",
            "Episode 493, Total Revenue: $18.00\n",
            "Episode 494, Total Revenue: $36.00\n",
            "Episode 495, Total Revenue: $63.00\n",
            "Episode 496, Total Revenue: $81.00\n",
            "Episode 497, Total Revenue: $90.00\n",
            "Episode 498, Total Revenue: $9.00\n",
            "Episode 499, Total Revenue: $27.00\n",
            "Episode 500, Total Revenue: $36.00\n",
            "Episode 501, Total Revenue: $63.00\n",
            "Episode 502, Total Revenue: $45.00\n",
            "Episode 503, Total Revenue: $54.00\n",
            "Episode 504, Total Revenue: $54.00\n",
            "Episode 505, Total Revenue: $40.00\n",
            "Episode 506, Total Revenue: $36.00\n",
            "Episode 507, Total Revenue: $36.00\n",
            "Episode 508, Total Revenue: $27.00\n",
            "Episode 509, Total Revenue: $72.00\n",
            "Episode 510, Total Revenue: $45.00\n",
            "Episode 511, Total Revenue: $63.00\n",
            "Episode 512, Total Revenue: $81.00\n",
            "Episode 513, Total Revenue: $9.00\n",
            "Episode 514, Total Revenue: $81.00\n",
            "Episode 515, Total Revenue: $9.00\n",
            "Episode 516, Total Revenue: $18.00\n",
            "Episode 517, Total Revenue: $18.00\n",
            "Episode 518, Total Revenue: $72.00\n",
            "Episode 519, Total Revenue: $90.00\n",
            "Episode 520, Total Revenue: $45.00\n",
            "Episode 521, Total Revenue: $27.00\n",
            "Episode 522, Total Revenue: $36.00\n",
            "Episode 523, Total Revenue: $42.00\n",
            "Episode 524, Total Revenue: $90.00\n",
            "Episode 525, Total Revenue: $36.00\n",
            "Episode 526, Total Revenue: $90.00\n",
            "Episode 527, Total Revenue: $63.00\n",
            "Episode 528, Total Revenue: $4.00\n",
            "Episode 529, Total Revenue: $72.00\n",
            "Episode 530, Total Revenue: $18.00\n",
            "Episode 531, Total Revenue: $63.00\n",
            "Episode 532, Total Revenue: $9.00\n",
            "Episode 533, Total Revenue: $54.00\n",
            "Episode 534, Total Revenue: $63.00\n",
            "Episode 535, Total Revenue: $45.00\n",
            "Episode 536, Total Revenue: $63.00\n",
            "Episode 537, Total Revenue: $54.00\n",
            "Episode 538, Total Revenue: $54.00\n",
            "Episode 539, Total Revenue: $9.00\n",
            "Episode 540, Total Revenue: $22.00\n",
            "Episode 541, Total Revenue: $81.00\n",
            "Episode 542, Total Revenue: $70.00\n",
            "Episode 543, Total Revenue: $81.00\n",
            "Episode 544, Total Revenue: $72.00\n",
            "Episode 545, Total Revenue: $72.00\n",
            "Episode 546, Total Revenue: $45.00\n",
            "Episode 547, Total Revenue: $35.00\n",
            "Episode 548, Total Revenue: $81.00\n",
            "Episode 549, Total Revenue: $27.00\n",
            "Episode 550, Total Revenue: $54.00\n",
            "Episode 551, Total Revenue: $63.00\n",
            "Episode 552, Total Revenue: $90.00\n",
            "Episode 553, Total Revenue: $27.00\n",
            "Episode 554, Total Revenue: $36.00\n",
            "Episode 555, Total Revenue: $81.00\n",
            "Episode 556, Total Revenue: $9.00\n",
            "Episode 557, Total Revenue: $27.00\n",
            "Episode 558, Total Revenue: $63.00\n",
            "Episode 559, Total Revenue: $9.00\n",
            "Episode 560, Total Revenue: $81.00\n",
            "Episode 561, Total Revenue: $81.00\n",
            "Episode 562, Total Revenue: $36.00\n",
            "Episode 563, Total Revenue: $63.00\n",
            "Episode 564, Total Revenue: $72.00\n",
            "Episode 565, Total Revenue: $9.00\n",
            "Episode 566, Total Revenue: $81.00\n",
            "Episode 567, Total Revenue: $72.00\n",
            "Episode 568, Total Revenue: $45.00\n",
            "Episode 569, Total Revenue: $63.00\n",
            "Episode 570, Total Revenue: $18.00\n",
            "Episode 571, Total Revenue: $45.00\n",
            "Episode 572, Total Revenue: $81.00\n",
            "Episode 573, Total Revenue: $81.00\n",
            "Episode 574, Total Revenue: $90.00\n",
            "Episode 575, Total Revenue: $72.00\n",
            "Episode 576, Total Revenue: $72.00\n",
            "Episode 577, Total Revenue: $45.00\n",
            "Episode 578, Total Revenue: $18.00\n",
            "Episode 579, Total Revenue: $81.00\n",
            "Episode 580, Total Revenue: $7.00\n",
            "Episode 581, Total Revenue: $36.00\n",
            "Episode 582, Total Revenue: $45.00\n",
            "Episode 583, Total Revenue: $72.00\n",
            "Episode 584, Total Revenue: $36.00\n",
            "Episode 585, Total Revenue: $45.00\n",
            "Episode 586, Total Revenue: $18.00\n",
            "Episode 587, Total Revenue: $45.00\n",
            "Episode 588, Total Revenue: $18.00\n",
            "Episode 589, Total Revenue: $63.00\n",
            "Episode 590, Total Revenue: $45.00\n",
            "Episode 591, Total Revenue: $53.00\n",
            "Episode 592, Total Revenue: $81.00\n",
            "Episode 593, Total Revenue: $27.00\n",
            "Episode 594, Total Revenue: $72.00\n",
            "Episode 595, Total Revenue: $27.00\n",
            "Episode 596, Total Revenue: $63.00\n",
            "Episode 597, Total Revenue: $90.00\n",
            "Episode 598, Total Revenue: $72.00\n",
            "Episode 599, Total Revenue: $81.00\n",
            "Episode 600, Total Revenue: $45.00\n",
            "Episode 601, Total Revenue: $9.00\n",
            "Episode 602, Total Revenue: $45.00\n",
            "Episode 603, Total Revenue: $54.00\n",
            "Episode 604, Total Revenue: $81.00\n",
            "Episode 605, Total Revenue: $90.00\n",
            "Episode 606, Total Revenue: $6.00\n",
            "Episode 607, Total Revenue: $9.00\n",
            "Episode 608, Total Revenue: $27.00\n",
            "Episode 609, Total Revenue: $45.00\n",
            "Episode 610, Total Revenue: $36.00\n",
            "Episode 611, Total Revenue: $54.00\n",
            "Episode 612, Total Revenue: $27.00\n",
            "Episode 613, Total Revenue: $90.00\n",
            "Episode 614, Total Revenue: $36.00\n",
            "Episode 615, Total Revenue: $6.00\n",
            "Episode 616, Total Revenue: $27.00\n",
            "Episode 617, Total Revenue: $72.00\n",
            "Episode 618, Total Revenue: $45.00\n",
            "Episode 619, Total Revenue: $45.00\n",
            "Episode 620, Total Revenue: $63.00\n",
            "Episode 621, Total Revenue: $9.00\n",
            "Episode 622, Total Revenue: $81.00\n",
            "Episode 623, Total Revenue: $45.00\n",
            "Episode 624, Total Revenue: $54.00\n",
            "Episode 625, Total Revenue: $36.00\n",
            "Episode 626, Total Revenue: $9.00\n",
            "Episode 627, Total Revenue: $45.00\n",
            "Episode 628, Total Revenue: $9.00\n",
            "Episode 629, Total Revenue: $54.00\n",
            "Episode 630, Total Revenue: $81.00\n",
            "Episode 631, Total Revenue: $9.00\n",
            "Episode 632, Total Revenue: $90.00\n",
            "Episode 633, Total Revenue: $27.00\n",
            "Episode 634, Total Revenue: $72.00\n",
            "Episode 635, Total Revenue: $54.00\n",
            "Episode 636, Total Revenue: $81.00\n",
            "Episode 637, Total Revenue: $36.00\n",
            "Episode 638, Total Revenue: $18.00\n",
            "Episode 639, Total Revenue: $18.00\n",
            "Episode 640, Total Revenue: $36.00\n",
            "Episode 641, Total Revenue: $72.00\n",
            "Episode 642, Total Revenue: $90.00\n",
            "Episode 643, Total Revenue: $9.00\n",
            "Episode 644, Total Revenue: $54.00\n",
            "Episode 645, Total Revenue: $18.00\n",
            "Episode 646, Total Revenue: $54.00\n",
            "Episode 647, Total Revenue: $27.00\n",
            "Episode 648, Total Revenue: $90.00\n",
            "Episode 649, Total Revenue: $13.00\n",
            "Episode 650, Total Revenue: $45.00\n",
            "Episode 651, Total Revenue: $54.00\n",
            "Episode 652, Total Revenue: $90.00\n",
            "Episode 653, Total Revenue: $90.00\n",
            "Episode 654, Total Revenue: $16.00\n",
            "Episode 655, Total Revenue: $20.00\n",
            "Episode 656, Total Revenue: $72.00\n",
            "Episode 657, Total Revenue: $76.00\n",
            "Episode 658, Total Revenue: $28.00\n",
            "Episode 659, Total Revenue: $72.00\n",
            "Episode 660, Total Revenue: $63.00\n",
            "Episode 661, Total Revenue: $81.00\n",
            "Episode 662, Total Revenue: $63.00\n",
            "Episode 663, Total Revenue: $18.00\n",
            "Episode 664, Total Revenue: $21.00\n",
            "Episode 665, Total Revenue: $9.00\n",
            "Episode 666, Total Revenue: $72.00\n",
            "Episode 667, Total Revenue: $81.00\n",
            "Episode 668, Total Revenue: $90.00\n",
            "Episode 669, Total Revenue: $90.00\n",
            "Episode 670, Total Revenue: $90.00\n",
            "Episode 671, Total Revenue: $45.00\n",
            "Episode 672, Total Revenue: $9.00\n",
            "Episode 673, Total Revenue: $90.00\n",
            "Episode 674, Total Revenue: $72.00\n",
            "Episode 675, Total Revenue: $27.00\n",
            "Episode 676, Total Revenue: $9.00\n",
            "Episode 677, Total Revenue: $72.00\n",
            "Episode 678, Total Revenue: $72.00\n",
            "Episode 679, Total Revenue: $9.00\n",
            "Episode 680, Total Revenue: $9.00\n",
            "Episode 681, Total Revenue: $45.00\n",
            "Episode 682, Total Revenue: $9.00\n",
            "Episode 683, Total Revenue: $90.00\n",
            "Episode 684, Total Revenue: $9.00\n",
            "Episode 685, Total Revenue: $36.00\n",
            "Episode 686, Total Revenue: $27.00\n",
            "Episode 687, Total Revenue: $54.00\n",
            "Episode 688, Total Revenue: $72.00\n",
            "Episode 689, Total Revenue: $63.00\n",
            "Episode 690, Total Revenue: $61.00\n",
            "Episode 691, Total Revenue: $45.00\n",
            "Episode 692, Total Revenue: $25.00\n",
            "Episode 693, Total Revenue: $32.00\n",
            "Episode 694, Total Revenue: $45.00\n",
            "Episode 695, Total Revenue: $9.00\n",
            "Episode 696, Total Revenue: $81.00\n",
            "Episode 697, Total Revenue: $54.00\n",
            "Episode 698, Total Revenue: $27.00\n",
            "Episode 699, Total Revenue: $90.00\n",
            "Episode 700, Total Revenue: $45.00\n",
            "Episode 701, Total Revenue: $4.00\n",
            "Episode 702, Total Revenue: $63.00\n",
            "Episode 703, Total Revenue: $90.00\n",
            "Episode 704, Total Revenue: $76.00\n",
            "Episode 705, Total Revenue: $18.00\n",
            "Episode 706, Total Revenue: $45.00\n",
            "Episode 707, Total Revenue: $9.00\n",
            "Episode 708, Total Revenue: $45.00\n",
            "Episode 709, Total Revenue: $54.00\n",
            "Episode 710, Total Revenue: $81.00\n",
            "Episode 711, Total Revenue: $36.00\n",
            "Episode 712, Total Revenue: $45.00\n",
            "Episode 713, Total Revenue: $9.00\n",
            "Episode 714, Total Revenue: $27.00\n",
            "Episode 715, Total Revenue: $54.00\n",
            "Episode 716, Total Revenue: $54.00\n",
            "Episode 717, Total Revenue: $81.00\n",
            "Episode 718, Total Revenue: $9.00\n",
            "Episode 719, Total Revenue: $72.00\n",
            "Episode 720, Total Revenue: $20.00\n",
            "Episode 721, Total Revenue: $45.00\n",
            "Episode 722, Total Revenue: $54.00\n",
            "Episode 723, Total Revenue: $81.00\n",
            "Episode 724, Total Revenue: $36.00\n",
            "Episode 725, Total Revenue: $82.00\n",
            "Episode 726, Total Revenue: $36.00\n",
            "Episode 727, Total Revenue: $72.00\n",
            "Episode 728, Total Revenue: $18.00\n",
            "Episode 729, Total Revenue: $90.00\n",
            "Episode 730, Total Revenue: $18.00\n",
            "Episode 731, Total Revenue: $18.00\n",
            "Episode 732, Total Revenue: $72.00\n",
            "Episode 733, Total Revenue: $63.00\n",
            "Episode 734, Total Revenue: $81.00\n",
            "Episode 735, Total Revenue: $45.00\n",
            "Episode 736, Total Revenue: $36.00\n",
            "Episode 737, Total Revenue: $45.00\n",
            "Episode 738, Total Revenue: $45.00\n",
            "Episode 739, Total Revenue: $45.00\n",
            "Episode 740, Total Revenue: $36.00\n",
            "Episode 741, Total Revenue: $40.00\n",
            "Episode 742, Total Revenue: $18.00\n",
            "Episode 743, Total Revenue: $27.00\n",
            "Episode 744, Total Revenue: $63.00\n",
            "Episode 745, Total Revenue: $9.00\n",
            "Episode 746, Total Revenue: $9.00\n",
            "Episode 747, Total Revenue: $18.00\n",
            "Episode 748, Total Revenue: $63.00\n",
            "Episode 749, Total Revenue: $27.00\n",
            "Episode 750, Total Revenue: $36.00\n",
            "Episode 751, Total Revenue: $67.00\n",
            "Episode 752, Total Revenue: $54.00\n",
            "Episode 753, Total Revenue: $36.00\n",
            "Episode 754, Total Revenue: $63.00\n",
            "Episode 755, Total Revenue: $54.00\n",
            "Episode 756, Total Revenue: $27.00\n",
            "Episode 757, Total Revenue: $36.00\n",
            "Episode 758, Total Revenue: $36.00\n",
            "Episode 759, Total Revenue: $54.00\n",
            "Episode 760, Total Revenue: $54.00\n",
            "Episode 761, Total Revenue: $63.00\n",
            "Episode 762, Total Revenue: $27.00\n",
            "Episode 763, Total Revenue: $72.00\n",
            "Episode 764, Total Revenue: $54.00\n",
            "Episode 765, Total Revenue: $3.00\n",
            "Episode 766, Total Revenue: $63.00\n",
            "Episode 767, Total Revenue: $72.00\n",
            "Episode 768, Total Revenue: $18.00\n",
            "Episode 769, Total Revenue: $9.00\n",
            "Episode 770, Total Revenue: $72.00\n",
            "Episode 771, Total Revenue: $54.00\n",
            "Episode 772, Total Revenue: $36.00\n",
            "Episode 773, Total Revenue: $100.00\n",
            "Episode 774, Total Revenue: $54.00\n",
            "Episode 775, Total Revenue: $63.00\n",
            "Episode 776, Total Revenue: $27.00\n",
            "Episode 777, Total Revenue: $10.00\n",
            "Episode 778, Total Revenue: $27.00\n",
            "Episode 779, Total Revenue: $90.00\n",
            "Episode 780, Total Revenue: $40.00\n",
            "Episode 781, Total Revenue: $54.00\n",
            "Episode 782, Total Revenue: $72.00\n",
            "Episode 783, Total Revenue: $45.00\n",
            "Episode 784, Total Revenue: $27.00\n",
            "Episode 785, Total Revenue: $63.00\n",
            "Episode 786, Total Revenue: $27.00\n",
            "Episode 787, Total Revenue: $36.00\n",
            "Episode 788, Total Revenue: $72.00\n",
            "Episode 789, Total Revenue: $13.00\n",
            "Episode 790, Total Revenue: $18.00\n",
            "Episode 791, Total Revenue: $36.00\n",
            "Episode 792, Total Revenue: $72.00\n",
            "Episode 793, Total Revenue: $54.00\n",
            "Episode 794, Total Revenue: $72.00\n",
            "Episode 795, Total Revenue: $27.00\n",
            "Episode 796, Total Revenue: $70.00\n",
            "Episode 797, Total Revenue: $27.00\n",
            "Episode 798, Total Revenue: $90.00\n",
            "Episode 799, Total Revenue: $54.00\n",
            "Episode 800, Total Revenue: $37.00\n",
            "Episode 801, Total Revenue: $45.00\n",
            "Episode 802, Total Revenue: $63.00\n",
            "Episode 803, Total Revenue: $18.00\n",
            "Episode 804, Total Revenue: $63.00\n",
            "Episode 805, Total Revenue: $81.00\n",
            "Episode 806, Total Revenue: $72.00\n",
            "Episode 807, Total Revenue: $90.00\n",
            "Episode 808, Total Revenue: $54.00\n",
            "Episode 809, Total Revenue: $81.00\n",
            "Episode 810, Total Revenue: $9.00\n",
            "Episode 811, Total Revenue: $63.00\n",
            "Episode 812, Total Revenue: $27.00\n",
            "Episode 813, Total Revenue: $27.00\n",
            "Episode 814, Total Revenue: $54.00\n",
            "Episode 815, Total Revenue: $90.00\n",
            "Episode 816, Total Revenue: $36.00\n",
            "Episode 817, Total Revenue: $90.00\n",
            "Episode 818, Total Revenue: $76.00\n",
            "Episode 819, Total Revenue: $63.00\n",
            "Episode 820, Total Revenue: $9.00\n",
            "Episode 821, Total Revenue: $54.00\n",
            "Episode 822, Total Revenue: $90.00\n",
            "Episode 823, Total Revenue: $15.00\n",
            "Episode 824, Total Revenue: $27.00\n",
            "Episode 825, Total Revenue: $36.00\n",
            "Episode 826, Total Revenue: $63.00\n",
            "Episode 827, Total Revenue: $81.00\n",
            "Episode 828, Total Revenue: $36.00\n",
            "Episode 829, Total Revenue: $36.00\n",
            "Episode 830, Total Revenue: $27.00\n",
            "Episode 831, Total Revenue: $45.00\n",
            "Episode 832, Total Revenue: $90.00\n",
            "Episode 833, Total Revenue: $54.00\n",
            "Episode 834, Total Revenue: $9.00\n",
            "Episode 835, Total Revenue: $20.00\n",
            "Episode 836, Total Revenue: $27.00\n",
            "Episode 837, Total Revenue: $45.00\n",
            "Episode 838, Total Revenue: $45.00\n",
            "Episode 839, Total Revenue: $27.00\n",
            "Episode 840, Total Revenue: $45.00\n",
            "Episode 841, Total Revenue: $32.00\n",
            "Episode 842, Total Revenue: $36.00\n",
            "Episode 843, Total Revenue: $18.00\n",
            "Episode 844, Total Revenue: $63.00\n",
            "Episode 845, Total Revenue: $63.00\n",
            "Episode 846, Total Revenue: $36.00\n",
            "Episode 847, Total Revenue: $63.00\n",
            "Episode 848, Total Revenue: $9.00\n",
            "Episode 849, Total Revenue: $45.00\n",
            "Episode 850, Total Revenue: $27.00\n",
            "Episode 851, Total Revenue: $63.00\n",
            "Episode 852, Total Revenue: $9.00\n",
            "Episode 853, Total Revenue: $36.00\n",
            "Episode 854, Total Revenue: $54.00\n",
            "Episode 855, Total Revenue: $9.00\n",
            "Episode 856, Total Revenue: $54.00\n",
            "Episode 857, Total Revenue: $60.00\n",
            "Episode 858, Total Revenue: $18.00\n",
            "Episode 859, Total Revenue: $81.00\n",
            "Episode 860, Total Revenue: $9.00\n",
            "Episode 861, Total Revenue: $81.00\n",
            "Episode 862, Total Revenue: $18.00\n",
            "Episode 863, Total Revenue: $54.00\n",
            "Episode 864, Total Revenue: $9.00\n",
            "Episode 865, Total Revenue: $6.00\n",
            "Episode 866, Total Revenue: $9.00\n",
            "Episode 867, Total Revenue: $70.00\n",
            "Episode 868, Total Revenue: $36.00\n",
            "Episode 869, Total Revenue: $36.00\n",
            "Episode 870, Total Revenue: $81.00\n",
            "Episode 871, Total Revenue: $18.00\n",
            "Episode 872, Total Revenue: $54.00\n",
            "Episode 873, Total Revenue: $36.00\n",
            "Episode 874, Total Revenue: $36.00\n",
            "Episode 875, Total Revenue: $27.00\n",
            "Episode 876, Total Revenue: $30.00\n",
            "Episode 877, Total Revenue: $36.00\n",
            "Episode 878, Total Revenue: $81.00\n",
            "Episode 879, Total Revenue: $18.00\n",
            "Episode 880, Total Revenue: $18.00\n",
            "Episode 881, Total Revenue: $72.00\n",
            "Episode 882, Total Revenue: $54.00\n",
            "Episode 883, Total Revenue: $28.00\n",
            "Episode 884, Total Revenue: $18.00\n",
            "Episode 885, Total Revenue: $81.00\n",
            "Episode 886, Total Revenue: $52.00\n",
            "Episode 887, Total Revenue: $18.00\n",
            "Episode 888, Total Revenue: $70.00\n",
            "Episode 889, Total Revenue: $9.00\n",
            "Episode 890, Total Revenue: $9.00\n",
            "Episode 891, Total Revenue: $90.00\n",
            "Episode 892, Total Revenue: $63.00\n",
            "Episode 893, Total Revenue: $35.00\n",
            "Episode 894, Total Revenue: $54.00\n",
            "Episode 895, Total Revenue: $18.00\n",
            "Episode 896, Total Revenue: $27.00\n",
            "Episode 897, Total Revenue: $81.00\n",
            "Episode 898, Total Revenue: $36.00\n",
            "Episode 899, Total Revenue: $45.00\n",
            "Episode 900, Total Revenue: $36.00\n",
            "Episode 901, Total Revenue: $6.00\n",
            "Episode 902, Total Revenue: $27.00\n",
            "Episode 903, Total Revenue: $90.00\n",
            "Episode 904, Total Revenue: $9.00\n",
            "Episode 905, Total Revenue: $81.00\n",
            "Episode 906, Total Revenue: $81.00\n",
            "Episode 907, Total Revenue: $90.00\n",
            "Episode 908, Total Revenue: $9.00\n",
            "Episode 909, Total Revenue: $72.00\n",
            "Episode 910, Total Revenue: $54.00\n",
            "Episode 911, Total Revenue: $52.00\n",
            "Episode 912, Total Revenue: $72.00\n",
            "Episode 913, Total Revenue: $90.00\n",
            "Episode 914, Total Revenue: $90.00\n",
            "Episode 915, Total Revenue: $54.00\n",
            "Episode 916, Total Revenue: $9.00\n",
            "Episode 917, Total Revenue: $27.00\n",
            "Episode 918, Total Revenue: $9.00\n",
            "Episode 919, Total Revenue: $18.00\n",
            "Episode 920, Total Revenue: $27.00\n",
            "Episode 921, Total Revenue: $76.00\n",
            "Episode 922, Total Revenue: $63.00\n",
            "Episode 923, Total Revenue: $18.00\n",
            "Episode 924, Total Revenue: $54.00\n",
            "Episode 925, Total Revenue: $63.00\n",
            "Episode 926, Total Revenue: $9.00\n",
            "Episode 927, Total Revenue: $72.00\n",
            "Episode 928, Total Revenue: $63.00\n",
            "Episode 929, Total Revenue: $46.00\n",
            "Episode 930, Total Revenue: $81.00\n",
            "Episode 931, Total Revenue: $9.00\n",
            "Episode 932, Total Revenue: $86.00\n",
            "Episode 933, Total Revenue: $9.00\n",
            "Episode 934, Total Revenue: $90.00\n",
            "Episode 935, Total Revenue: $18.00\n",
            "Episode 936, Total Revenue: $63.00\n",
            "Episode 937, Total Revenue: $18.00\n",
            "Episode 938, Total Revenue: $9.00\n",
            "Episode 939, Total Revenue: $90.00\n",
            "Episode 940, Total Revenue: $90.00\n",
            "Episode 941, Total Revenue: $45.00\n",
            "Episode 942, Total Revenue: $81.00\n",
            "Episode 943, Total Revenue: $54.00\n",
            "Episode 944, Total Revenue: $36.00\n",
            "Episode 945, Total Revenue: $18.00\n",
            "Episode 946, Total Revenue: $90.00\n",
            "Episode 947, Total Revenue: $63.00\n",
            "Episode 948, Total Revenue: $15.00\n",
            "Episode 949, Total Revenue: $18.00\n",
            "Episode 950, Total Revenue: $72.00\n",
            "Episode 951, Total Revenue: $81.00\n",
            "Episode 952, Total Revenue: $36.00\n",
            "Episode 953, Total Revenue: $81.00\n",
            "Episode 954, Total Revenue: $81.00\n",
            "Episode 955, Total Revenue: $34.00\n",
            "Episode 956, Total Revenue: $45.00\n",
            "Episode 957, Total Revenue: $72.00\n",
            "Episode 958, Total Revenue: $18.00\n",
            "Episode 959, Total Revenue: $9.00\n",
            "Episode 960, Total Revenue: $63.00\n",
            "Episode 961, Total Revenue: $81.00\n",
            "Episode 962, Total Revenue: $81.00\n",
            "Episode 963, Total Revenue: $18.00\n",
            "Episode 964, Total Revenue: $14.00\n",
            "Episode 965, Total Revenue: $63.00\n",
            "Episode 966, Total Revenue: $18.00\n",
            "Episode 967, Total Revenue: $81.00\n",
            "Episode 968, Total Revenue: $27.00\n",
            "Episode 969, Total Revenue: $36.00\n",
            "Episode 970, Total Revenue: $45.00\n",
            "Episode 971, Total Revenue: $9.00\n",
            "Episode 972, Total Revenue: $90.00\n",
            "Episode 973, Total Revenue: $34.00\n",
            "Episode 974, Total Revenue: $90.00\n",
            "Episode 975, Total Revenue: $36.00\n",
            "Episode 976, Total Revenue: $54.00\n",
            "Episode 977, Total Revenue: $45.00\n",
            "Episode 978, Total Revenue: $72.00\n",
            "Episode 979, Total Revenue: $81.00\n",
            "Episode 980, Total Revenue: $9.00\n",
            "Episode 981, Total Revenue: $90.00\n",
            "Episode 982, Total Revenue: $45.00\n",
            "Episode 983, Total Revenue: $81.00\n",
            "Episode 984, Total Revenue: $81.00\n",
            "Episode 985, Total Revenue: $90.00\n",
            "Episode 986, Total Revenue: $63.00\n",
            "Episode 987, Total Revenue: $82.00\n",
            "Episode 988, Total Revenue: $76.00\n",
            "Episode 989, Total Revenue: $45.00\n",
            "Episode 990, Total Revenue: $3.00\n",
            "Episode 991, Total Revenue: $27.00\n",
            "Episode 992, Total Revenue: $45.00\n",
            "Episode 993, Total Revenue: $27.00\n",
            "Episode 994, Total Revenue: $54.00\n",
            "Episode 995, Total Revenue: $36.00\n",
            "Episode 996, Total Revenue: $27.00\n",
            "Episode 997, Total Revenue: $36.00\n",
            "Episode 998, Total Revenue: $63.00\n",
            "Episode 999, Total Revenue: $72.00\n",
            "Episode 1000, Total Revenue: $81.00\n",
            "Optimal Price for current demand (8): $9\n"
          ]
        }
      ]
    }
  ]
}
# Out:
# {'nbformat': 4,
#  'nbformat_minor': 0,
#  'metadata': {'colab': {'provenance': []},
#   'kernelspec': {'name': 'python3', 'display_name': 'Python 3'},
#   'language_info': {'name': 'python'}},
#  'cells': [{'cell_type': 'markdown',
#    'source': ['\n',
#     '\n',
#     '*  An Environment, which an agent will interact with, to learn to reach a goal or perform an action.\n',
#     '\n',
#     'A Reward if the action performed by the model is bringing\n',
#     'us closer to the goal/is leading to the goal. This is done to train the model in the right direction.\n',
#     '\n',
#     'A negative reward if it performs an action that will not lead to the goal to prevent it from learning in the wrong direction.\n',
#     '\n'],
#    'metadata': {'id': 'l9nMxmd0tv99'}},
#   {'cell_type': 'code',
#    'source': ['import numpy as np\n',
#     '\n',
#     'class PricingEnvironment:\n',
#     '    def __init__(self, max_demand, max_price):\n',
#     '        self.max_demand = max_demand\n',
# ...

# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": []
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "code",
      "source": [
        "import numpy as np\n",
        "\n",
        "class SimpleMDP:\n",
        "    def __init__(self):\n",
        "        self.num_states = 3\n",
        "        self.num_actions = 2\n",
        "        self.transitions = np.zeros((self.num_states, self.num_actions, self.num_states)) # transition probabilities\n",
        "        self.rewards = np.zeros((self.num_states, self.num_actions)) # rewards\n",
        "\n",
        "        # Define transition probabilities and rewards\n",
        "        self.transitions[0, 0, :] = [0.7, 0.3, 0.0]\n",
        "        self.transitions[0, 1, :] = [0.0, 0.9, 0.1]\n",
        "        self.transitions[1, 0, :] = [0.0, 1.0, 0.0]\n",
        "        self.transitions[1, 1, :] = [0.8, 0.2, 0.0]\n",
        "        self.transitions[2, :, :] = [0.0, 0.0, 1.0]\n",
        "        self.rewards[1, 0] = 1.0\n",
        "        self.rewards[1, 1] = 1.0\n",
        "        self.rewards[2, :] = 10.0\n",
        "\n",
        "    def step(self, state, action):\n",
        "        next_state_probs = self.transitions[state, action, :]\n",
        "        next_state = np.random.choice(self.num_states, p=next_state_probs)\n",
        "        reward = self.rewards[state, action]\n",
        "        return next_state, reward\n",
        "\n",
        "class QLearningAgent:\n",
        "    def __init__(self, num_states, num_actions, learning_rate=0.1, discount_factor=0.9, epsilon=0.1):\n",
        "        self.num_states = num_states\n",
        "        self.num_actions = num_actions\n",
        "        self.learning_rate = learning_rate\n",
        "        self.discount_factor = discount_factor\n",
        "        self.epsilon = epsilon\n",
        "        self.q_table = np.zeros((num_states, num_actions))\n",
        "\n",
        "    def choose_action(self, state):\n",
        "        if np.random.rand() < self.epsilon:\n",
        "            return np.random.choice(self.num_actions)\n",
        "        else:\n",
        "            return np.argmax(self.q_table[state, :])\n",
        "\n",
        "    def update_q_table(self, state, action, reward, next_state):\n",
        "        best_next_action = np.argmax(self.q_table[next_state, :])\n",
        "        td_target = reward + self.discount_factor * self.q_table[next_state, best_next_action]\n",
        "        td_error = td_target - self.q_table[state, action]\n",
        "        self.q_table[state, action] += self.learning_rate * td_error\n",
        "\n",
        "# Create MDP\n",
        "mdp = SimpleMDP()\n",
        "\n",
        "# Create Q-learning agent\n",
        "agent = QLearningAgent(num_states=mdp.num_states, num_actions=mdp.num_actions)\n",
        "\n",
        "# Training\n",
        "num_episodes = 1000\n",
        "for episode in range(num_episodes):\n",
        "    state = np.random.randint(mdp.num_states) # Start from a random state\n",
        "    while state != 2: # Continue until reaching the terminal state\n",
        "        action = agent.choose_action(state)\n",
        "        next_state, reward = mdp.step(state, action)\n",
        "        agent.update_q_table(state, action, reward, next_state)\n",
        "        state = next_state\n",
        "\n",
        "# Evaluate\n",
        "total_rewards = 0\n",
        "num_eval_episodes = 100\n",
        "for episode in range(num_eval_episodes):\n",
        "    state = 0\n",
        "    while state != 2:\n",
        "        action = agent.choose_action(state)\n",
        "        next_state, reward = mdp.step(state, action)\n",
        "        total_rewards += reward\n",
        "        state = next_state\n",
        "\n",
        "average_reward = total_rewards / num_eval_episodes\n",
        "print(\"Average reward over\", num_eval_episodes, \"evaluation episodes:\", average_reward)\n"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "P7BEHAYRbcB5",
        "outputId": "636dfebe-38af-4f42-98bc-b01ed7f7d2b0"
      },
      "execution_count": 14,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Average reward over 100 evaluation episodes: 1618.62\n"
          ]
        }
      ]
    }
  ]
}
# Out:
# {'nbformat': 4,
#  'nbformat_minor': 0,
#  'metadata': {'colab': {'provenance': []},
#   'kernelspec': {'name': 'python3', 'display_name': 'Python 3'},
#   'language_info': {'name': 'python'}},
#  'cells': [{'cell_type': 'code',
#    'source': ['import numpy as np\n',
#     '\n',
#     'class SimpleMDP:\n',
#     '    def __init__(self):\n',
#     '        self.num_states = 3\n',
#     '        self.num_actions = 2\n',
#     '        self.transitions = np.zeros((self.num_states, self.num_actions, self.num_states)) # transition probabilities\n',
#     '        self.rewards = np.zeros((self.num_states, self.num_actions)) # rewards\n',
#     '\n',
#     '        # Define transition probabilities and rewards\n',
#     '        self.transitions[0, 0, :] = [0.7, 0.3, 0.0]\n',
#     '        self.transitions[0, 1, :] = [0.0, 0.9, 0.1]\n',
#     '        self.transitions[1, 0, :] = [0.0, 1.0, 0.0]\n',
#     '        self.transitions[1, 1, :] = [0.8, 0.2, 0.0]\n',
# ...
